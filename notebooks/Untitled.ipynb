# %%
import duckdb
import pandas
import os

# %%
os.chdir("..")

# %%
con = duckdb.connect("uk_car_analyser.duckdb")
con.execute(f"""select make,count(*) as count FROM 'data/mot_last_test.parquet' group by make order by count""").df()
# Out:
#                                       make     count
# 0                                  EUROPED         1
# 1                              BMW 318I ES         1
# 2     AUDI A4 QUATTRO SPORTLINE V6 FSI 3.2         1
# 3                         BMW 330I SE AUTO         1
# 4                         BMW 330 CI  3.3L         1
# ...                                    ...       ...
# 3143                               RENAULT   3205547
# 3144                               PEUGEOT   3775481
# 3145                            VOLKSWAGEN   5510738
# 3146                              VAUXHALL   7448517
# 3147                                  FORD  10537735
#
# [3148 rows x 2 columns]
